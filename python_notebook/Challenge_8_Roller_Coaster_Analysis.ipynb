# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
url = 'https://raw.githubusercontent.com/kedeisha1/Challenges/main/coaster_db.csv'
df=pd.read_csv(url)
df
# Out:
#                                 coaster_name                Length
# 0                         Switchback Railway        600 ft (180 m)  \
# 1                          Flip Flap Railway                   NaN
# 2     Switchback Railway (Euclid Beach Park)                   NaN
# 3               Loop the Loop (Coney Island)                   NaN
# 4               Loop the Loop (Young's Pier)                   NaN
# ...                                      ...                   ...
# 1082                 American Dreier Looping    3,444 ft (1,050 m)
# 1083               Pantheon (roller coaster)    3,328 ft (1,014 m)
# 1084               Tron Lightcycle Power Run  3,169.3 ft (966.0 m)
# 1085                                 Tumbili        770 ft (230 m)
# 1086          Wonder Woman Flight of Courage    3,300 ft (1,000 m)
#
#                         Speed                        Location
# 0            6 mph (9.7 km/h)                    Coney Island  \
# ...

# %% [markdown]
# **How many columns and rows are in the dataset?**

# %%
len(df),len(df.columns)
# Out:
# (1087, 56)

# %% [markdown]
# **Is there any missing data?**

# %%
df.isnull().values.sum()
# Out:
# 29435

# %% [markdown]
# **Display the summary statistics of the numeric columns using the describe method.**

# %%
df.describe()
# Out:
#        Inversions  year_introduced    latitude   longitude  speed1_value
# count  932.000000      1087.000000  812.000000  812.000000    937.000000  \
# mean     1.547210      1994.986201   38.373484  -41.595373     53.850374
# std      2.114073        23.475248   15.516596   72.285227     23.385518
# min      0.000000      1884.000000  -48.261700 -123.035700      5.000000
# 25%      0.000000      1989.000000   35.031050  -84.552200     40.000000
# 50%      0.000000      2000.000000   40.289800  -76.653600     50.000000
# 75%      3.000000      2010.000000   44.799600    2.778100     63.000000
# max     14.000000      2022.000000   63.230900  153.426500    240.000000
#
#         speed_mph  height_value   height_ft  Inversions_clean  Gforce_clean
# count  937.000000    965.000000  171.000000       1087.000000    362.000000
# mean    48.617289     89.575171  101.996491          1.326587      3.824006
# std     16.678031    136.246444   67.329092          2.030854      0.989998
# ...

# %% [markdown]
# ***Rename the following columns:
# coaster_name ➡️  Coaster_Name
# year_introduced ➡️ Year_Introduced
# opening_date_clean ➡️ Opening_Date
# speed_mph ➡️ Speed_mph
# height_ft ➡️ Height_ft
# Inversions_clean ➡️ Inversions
# Gforce_clean ➡️ Gforce***

# %%
df.rename(columns={'coaster_name':'Coaster_Name', 'year_introduced':'Year_Introduced','opening_date_clean':'Opening_Date',
             'speed_mph':'Speed_mph', 'height_ft':'Height_ft', 'Inversions_clean':'Inversions','Gforce_clean':'Gforce'})
df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %% [markdown]
# **Are there any duplicated rows?**

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **What are the top 3 years with the most roller coasters introduced?**

# %%
pd.to_datetime(df['opening_date_clean']).dt.year.value_counts().head(3)
#year_column=pd.to_datetime(df['opening_date_clean']).dt.year
# df.groupby(year_column)['coaster_name'].count().sort_values(ascending=False).head(3)
# Out:
# opening_date_clean
# 1999.0    38
# 2000.0    36
# 2002.0    26
# Name: count, dtype: int64

# %% [markdown]
# **What is the average speed? Also display a plot to show it’s distribution.**

# %%
round(df['speed_mph'].mean(),2)
# Out:
# 48.62

# %%
plt.hist(df['speed_mph'])
plt.title("Distribution of Roller Coaster Speeds")
plt.xlabel("Speed (mph)")
plt.ylabel("Number of Roller Coasters")
plt.show()

# %% [markdown]
# **Explore the feature relationships. Are there any positively or negatively correlated relationships?**

# %%
df.corr(numeric_only=True)
# Out:
#                   Inversions  year_introduced  latitude  longitude
# Inversions          1.000000         0.211003 -0.009815   0.061589  \
# year_introduced     0.211003         1.000000 -0.070982   0.175913
# latitude           -0.009815        -0.070982  1.000000  -0.298488
# longitude           0.061589         0.175913 -0.298488   1.000000
# speed1_value        0.163419         0.210191 -0.121847   0.301179
# speed_mph           0.252209         0.204853 -0.063757   0.051063
# height_value        0.094811         0.087687 -0.004265  -0.092764
# height_ft           0.171330         0.232150  0.011492   0.159733
# Inversions_clean    1.000000         0.228758 -0.014043   0.087160
# Gforce_clean        0.356865        -0.066657  0.042871   0.016485
#
#                   speed1_value  speed_mph  height_value  height_ft
# Inversions            0.163419   0.252209      0.094811   0.171330  \
# year_introduced       0.210191   0.204853      0.087687   0.232150
# ...

# %% [markdown]
# **Create your own question and answer it.**

# %%
status_count=df.groupby(df['Status'])['speed_mph'].mean()
status_count
# Out:
# Status
# Chapter 7 bankruptcy; rides dismantled and sold; property sold          NaN
# Closed                                                            65.642857
# Closed in 2021                                                    40.000000
# Discontinued                                                            NaN
# In Production                                                     53.133333
# Not Currently Operating                                           49.700000
# Operating                                                         50.171711
# Removed                                                           44.652083
# SBNO (Standing But Not Operating)                                 65.000000
# SBNO December 2019                                                54.700000
# Temporarily Closed                                                50.000000
# Temporarily closed                                                70.000000
# ...

# %%
status_count.plot(kind = 'barh', x = 'Status', y = 'Avg. Speed (mph)',figsize=(5,5),title='Avg. Speed by Location')
plt.show()
