# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('../datasets/titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass
# 0            892         0       3  \
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch
# 0                                Kelly, Mr. James    male  34.5      0      0  \
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.isnull()
# Out:
#              Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket
# PassengerId
# 892             False   False  False  False  False  False  False   False  \
# 893             False   False  False  False  False  False  False   False
# 894             False   False  False  False  False  False  False   False
# 895             False   False  False  False  False  False  False   False
# 896             False   False  False  False  False  False  False   False
# ...               ...     ...    ...    ...    ...    ...    ...     ...
# 1305            False   False  False  False  False  False  False   False
# 1306            False   False  False  False  False  False  False   False
# 1307            False   False  False  False  False  False  False   False
# 1308            False   False  False  False  False  False  False   False
# 1309            False   False  False  False  False  False  False   False
#
#               Fare  Cabin  Embarked
# PassengerId
# ...

# %%
df.fillna('NA',inplace=True)

# %% [markdown]
# **Set PassengerId as the index.**

# %%
df.set_index("PassengerId", inplace = True)
df.head()
# Out:
#              Survived  Pclass                                          Name
# PassengerId
# 892                 0       3                              Kelly, Mr. James  \
# 893                 1       3              Wilkes, Mrs. James (Ellen Needs)
# 894                 0       2                     Myles, Mr. Thomas Francis
# 895                 0       3                              Wirz, Mr. Albert
# 896                 1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#
#                 Sex   Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# PassengerId
# 892            male  34.5      0      0   330911   7.8292   NaN        Q
# 893          female  47.0      1      0   363272   7.0000   NaN        S
# 894            male  62.0      0      0   240276   9.6875   NaN        Q
# 895            male  27.0      0      0   315154   8.6625   NaN        S
# 896          female  22.0      1      1  3101298  12.2875   NaN        S

# %% [markdown]
# **Create a pie chart presenting the male/female as proportions**

# %%
gender=df.groupby('Sex')['Sex'].value_counts()
gender.plot(kind='pie',title='Male/Female Proportions',figsize=(4, 4),autopct='%1.0f%%',colors=['yellow','orange'],shadow=True)
# Out:
# <Axes: title={'center': 'Male/Female Proportions'}, ylabel='count'>

# %% [markdown]
# **Create a scatterplot with the Fare payed and the Age, differ the plot color by gender**

# %%
plt.figure() 
category1 = df[df.Sex=='male'].plot.scatter('Age', 'Fare', color='blue',label='male') 
df[df.Sex=='female'].plot.scatter('Age', 'Fare',color='red',label='female',ax=category1)
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %% [markdown]
# **How many people survived?**

# %%
df['Survived'].loc[df['Survived']==1].count()
# Out:
# 152

# %% [markdown]
# **Create a histogram with the Fare payed**

# %%
df.hist(column='Fare')
# Out:
# array([[<Axes: title={'center': 'Fare'}>]], dtype=object)

# %% [markdown]
# **BONUS: Create your own question and answer it.**

# %%
# Finding statistics for Pclass
df['Pclass'].describe()
# Out:
# count    418.000000
# mean       2.265550
# std        0.841838
# min        1.000000
# 25%        1.000000
# 50%        3.000000
# 75%        3.000000
# max        3.000000
# Name: Pclass, dtype: float64
